# %% [markdown]
# # <i> Assignament 4: Become an independent data Scientist</i>

# %% [markdown]
# ## ORGANISATION FOR ECONOMIC CO-OPERATION AND DEVELOPMENT(OECD)
# <h3>1-Region and Domain</h3>
#  - https://data.oecd.org/
#
# <h3>ORGANISATION FOR ECONOMIC CO-OPERATION AND DEVELOPMENT(OECD)</h3>
#
# OCDE en français
#
#
# - OECD Centres Around the World
#
#
#     OCDE in Spanish
#
#     OECD in German
#
#     OECD in Japanese
#
#     OECD Washington
#
#
#
# <h3>2-Research Question</h3>  <br>
#
#  - which country has the highest Unemployment rate from the dataset from year 2010-2023
#  - which country decreases Unimployment rate on this given years
#  - which country increases Unemployment rate
#  - create a line chart for countries such as `G7M, EU27,KOR,USA and AUS` from 2010-2020<br>
#
# **compare the all aged dataset with group by age under 15-24 and create a bar chart**
#  - show the relationship of countries for year 2020 from all aged dataset with respect to unemployment rate of 15-24 aged youngsters <br>
#
# <br>
# <h3>3-links</h3> <br>
#
#   UNEMPLOYMENT RATE BY AGE GROUP <i>FULL INDICATOR DATA (used)</i>
#
#  - https://stats.oecd.org/sdmx-json/data/DP_LIVE/.UNEMP.../OECD?contentType=csv&detail=code&separator=comma&csv-lang=en
#
#  UNEMPLOYMENT RATE BY AGE GROUP <i>SELECTED DATA ONLY(used)</i>
#
#  - https://data.oecd.org/unemp/unemployment-rate-by-age-group.htm
#
#  Additional datasets
#
#  UNEMPLOYMENT RATE <i>FULL DATA INDICATOR</i>
#  - https://stats.oecd.org/sdmx-json/data/DP_LIVE/.HUR.../OECD?contentType=csv&detail=code&separator=comma&csv-lang=en
#
#   UNEMPLOYMENT RATE <i>SELECTED DATA ONLY</i>
#
#  - https://stats.oecd.org/sdmx-json/data/DP_LIVE/.HUR.TOT.PC_LF.M/OECD?contentType=csv&detail=code&separator=comma&csv-lang=en&startPeriod=2005
#  <br>

# %% [markdown]
# ## OECD EMPLOYMENT AND LABOUR MARKET STATISTICS
#
#
# **ORGANISATION FOR ECONOMIC CO-OPERATION AND DEVELOPMENT**
#
# The OECD Employment and Labour Market Statistics database includes a range of annual labour market statistics and indicators from 1960 broken down by sex and age as well as information about part-time and short-time workers, job tenure, hours worked, unemployment duration, trade union, employment protection legislation, minimum wages, labour market programmes for OECD countries and non-member economies.unemployment among total unemployment by sex and by standardised age groups (15-19, 15-24, 20-24, 25-54, 55+, total). Data are expressed as percentages

# %% [markdown]
# As 2022 clearly illustrated the global job market can suprise expectations
# so far this year is not differ the unemployment rate of six of G7 countries hovers near the lowest in a century with an employment ate of 3.4%. the united state jobless rate has't fallen this since 1969.
# But as some economies navigate a strong labor against high infilation and hawkish monetary policy , others are facing more challenging comnditions. in the above graph we mAP unemployment forecast in 2023 using data from `IMF's World Economic Outlook`
#
# across many countries , the pandamic has made entriched labour trends worse. It has also altered job market conditions.
# South africa is projected to see the highest job less rate globally .As the most industrilized countries on the continent unemployment is estimted to hit 35.6%in 2023.
# together slow economic growth and stringent labour laws have prevented firms from hiring workers . Over th last two decades , Unemployment has hovered around 20%
# In europe Bosnia and Herzegovina is estimated to see the highest unemployment rate, at over 17%. it is followed by North Machedonia (15%) and spain(12.7%)
# the U.S is forecst to see an unemployment rate of 4.6% or 1.2 % higher than current leverl

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as nsn

# %%
# pd.options.display.max_row=100
# pd.options.display.max_columns

# %% [markdown]
# ## 1- Unemployment rate Full Data Indicator_by_age

# %%
full_unemployment_by_age = pd.read_csv('DP_LIVE_22022023073417405.csv',sep='\t')
full_unemployment_by_age.head()
# Out:
#   LOCATION INDICATOR SUBJECT   MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0      AUS   LTUNEMP     TOT  PC_UNEMP         A  1978  14.420246         NaN
# 1      AUS   LTUNEMP     TOT  PC_UNEMP         A  1979  18.128151         NaN
# 2      AUS   LTUNEMP     TOT  PC_UNEMP         A  1980  19.175518         NaN
# 3      AUS   LTUNEMP     TOT  PC_UNEMP         A  1981  19.501123         NaN
# 4      AUS   LTUNEMP     TOT  PC_UNEMP         A  1982  18.759181         NaN

# %% [markdown]
# ## Unemployment rate selected  Data only_by_age

# %%
select_age=pd.read_csv('DP_LIVE_02032023062306194.csv')
select_age.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME     Value Flag Codes
# 0      AUS       HUR     TOT   PC_LF         M  2005-01  5.073448        NaN
# 1      AUS       HUR     TOT   PC_LF         M  2005-02  5.083936        NaN
# 2      AUS       HUR     TOT   PC_LF         M  2005-03  5.162487        NaN
# 3      AUS       HUR     TOT   PC_LF         M  2005-04  5.121699        NaN
# 4      AUS       HUR     TOT   PC_LF         M  2005-05  5.098753        NaN

# %% [markdown]
# ## Unemployment rate full  Data indicator

# %%
unemp_full=pd.read_csv('DP_LIVE_02032023061921955.csv')
unemp_full.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value Flag Codes
# 0      GBR     UNEMP   15_24   PC_LF         A  1983  19.625        NaN
# 1      GBR     UNEMP   15_24   PC_LF         A  1984  18.725        NaN
# 2      GBR     UNEMP   15_24   PC_LF         A  1985  17.975        NaN
# 3      GBR     UNEMP   15_24   PC_LF         A  1986  17.725        NaN
# 4      GBR     UNEMP   15_24   PC_LF         A  1987  15.125        NaN

# %% [markdown]
# ## Unemployment selected

# %%
select_unemp=pd.read_csv('DP_LIVE_02032023064846433.csv')
select_unemp.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME     Value Flag Codes
# 0      AUS       HUR     TOT   PC_LF         M  2005-01  5.073448        NaN
# 1      AUS       HUR     TOT   PC_LF         M  2005-02  5.083936        NaN
# 2      AUS       HUR     TOT   PC_LF         M  2005-03  5.162487        NaN
# 3      AUS       HUR     TOT   PC_LF         M  2005-04  5.121699        NaN
# 4      AUS       HUR     TOT   PC_LF         M  2005-05  5.098753        NaN

# %%
full_unemployment_by_age.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
#remove Flag Codes from dataset
full_unemployment_by_age = full_unemployment_by_age[['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
       'Value']]

# %%
full_unemployment_by_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606 entries, 0 to 1605
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LOCATION   1606 non-null   object
#  1   INDICATOR  1606 non-null   object
#  2   SUBJECT    1606 non-null   object
#  3   MEASURE    1606 non-null   object
#  4   FREQUENCY  1606 non-null   object
#  5   TIME       1606 non-null   int64
#  6   Value      1606 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 88.0+ KB

# %%
full_unemployment_by_age.LOCATION.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'G7M', 'BGR', 'HRV', 'CYP', 'EST', 'ISR',
#        'LVA', 'LTU', 'MKD', 'MLT', 'RUS', 'SVN', 'ZAF', 'OECD', 'ROU',
#        'COL', 'CRI', 'NAM', 'EU27'], dtype=object)

# %%
# lets create a table from the year 2010 on word
beyond_2010 = full_unemployment_by_age[full_unemployment_by_age.TIME >= 2010]

# %%
G7M = beyond_2010[beyond_2010['LOCATION']=='G7M']
EU27 = beyond_2010[beyond_2010['LOCATION']=='EU27']
KOR = beyond_2010[beyond_2010['LOCATION']=='KOR']
USA = beyond_2010[beyond_2010['LOCATION']=='USA']
MKD = beyond_2010[beyond_2010['LOCATION']=='MKD']

# %%
plt.style.use('fivethirtyeight')

# %%
# %matplotlib inline

plt.figure(figsize=(10,7),dpi=300)
plt.plot('TIME','Value','--o',color='blue',data=G7M)
# plt.plot('TIME','Value',data=aus)
plt.title('Line graph of Unemployment rate for countries \n G7M, EU27,KOR,USA and AUS from 2010-2020',fontdict={'fontname':'Fantasy','fontsize':15},pad=25)
plt.plot("TIME","Value",'-s',color='#12fcda',data=EU27,label='EU27')
plt.plot("TIME","Value",'-p',color='#bcd12a',data=USA,label='USA')
plt.plot("TIME","Value",'-o',color='rebeccapurple',data=MKD,label='MKD')
plt.plot("TIME","Value",'-d',color='darkslategray',data=KOR,label='KOR')
label=['G7','EU27','USA','MKD','KOR']
plt.ylabel('valuesof Unemployment',fontdict={'fontname':'Cursive','fontsize':15})
plt.xlabel('Years',fontdict={'fontname':'Fantasy','fontsize':15})
plt.legend(label)
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %% [markdown]
# **From the abave graph of Unemploymet rate we will get that**
#
#  - MKD -Mekedonia has the highest unemployment rate from year 2010 to 2020
#  - KOR - Korea has a steady flow of Unemployment rate and it has the least value
#  - EU,USA and G7 countries have a graph that was fallen in year 2019 to 2020 but suddenly turned up
#    - **what is the case:**
#    - The first human cases of COVID-19 were identified in `Wuhan`, People's Republic of `China`, in December 2019. The World Health Organization declared the COVID-19 outbreak a Public Health Emergency of International Concern on 30 January 2020, and a pandemic on 11 March 2020.Due to this pandamic most countries increase their unemployment rate

# %% [markdown]
# ### Types of Unemployment
#
# 1. Demand deficient unemployment
# Demand deficit unemployment is the biggest cause of unemployment that typically happens during a recession. When companies experience a reduction in the demand for their products or services, they respond by cutting back on their production, making it necessary to reduce their workforce within the organization.
#
# 2. Frictional unemployment
# Frictional unemployment refers to those workers who are in between jobs. An example is a worker who recently quit or was fired and is looking for a job in an economy that is not experiencing a recession. It is not an unhealthy thing because it is usually caused by workers trying to find a job that is most suitable to their skills.
#
# 3. Structural unemployment
# Structural unemployment happens when the skills set of a worker does not match the skills demanded by the jobs available, or alternatively when workers are available but are unable to reach the geographical location of the jobs.
#
# 4. Voluntary unemployment
# Voluntary unemployment happens when a worker decides to leave a job because it is no longer financially compelling. An example is a worker whose take-home pay is less than his or her cost of living.
#
#
#
# #### Long-term Unemployment vs. Short-term Unemployment
# Unemployment that lasts longer than 27 weeks even if the individual has sought employment in the last four weeks is called long-term unemployment. Its effects are far worse than short-term unemployment for obvious reasons, and the following are noted as some of its effects.

# %% [markdown]
# ## Bar Graph

# %% [markdown]
# Let create a bar graph based on the full aged dataset for year  2010 and year  2020 separatly and then stack it together

# %%
#generating Random colors for individual bar
from random import randint

color = []
n = 48

for i in range(n):
    color.append('#%06X' % randint(0, 0xFFFFFF))

# %%
# %matplotlib inline
plt.figure(figsize=(10,7),dpi=200)
# create dataset that represent 2010
y_2010 =full_unemployment_by_age[full_unemployment_by_age.TIME==2010]
# create dataset that represent 2020
y_2020 =full_unemployment_by_age[full_unemployment_by_age.TIME==2020]
plt.title('Unemployment rate of countries on year 2010 and 2020',fontdict={'fontsize':23,'fontname':'Sans-serif'},pad=20)

#sorte the values based on their Values
y_2010 = y_2010.sort_values(by='Value')
unemp=plt.bar('LOCATION','Value',data=y_2010,color=color)
plt.bar('LOCATION','Value',data=y_2020,color='fuchsia',alpha=.5)
unemp[0].set_hatch('*')
# unemp[10].set_color('#23dfab')
unemp[-1].set_hatch('o')
# unemp[25].set_color('#4dbbcc')
plt.xticks(rotation='vertical')
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %% [markdown]
# **form the graph we can understand that**
#  - many of the countries decrease their unemployment rate from year 2010 in 2020 except
#   countries such as `NZL,CYP,GRC,ITA and ZAf` increase thier Unemployment rate from 2010 in 2020
#   But almost all countries decrease their unemployment rate  in 2020 than 2010 from

# %%
beyond_2010.TIME.max()
# Out:
# 2021

# %%
beyond_2010.TIME.min()
# Out:
# 2010

# %% [markdown]
# ## TASK 2
# <h3> Compare the average unemployment rate of countries form full aged dataset \n
# and Unemployment rate grouped age 15-24 from 2022-01 to 2023-01</h3>

# %%
# %matplotlib notebook
plt.figure(figsize=(15,7))
sample_une= beyond_2010.groupby('LOCATION')['Value'].mean().reset_index()
by_mean=sample_une.sort_values(by='Value',ascending= True)
bars = plt.bar('LOCATION','Value',data=by_mean,color=color)

plt.title('Mean results of Unemployment of countries from 2010 up to 2020',pad=25,fontsize=20)
plt.xticks(rotation='vertical')
plt.yticks([])
for spine in plt.gca().spines.values():
    spine.set_visible(False)
for bar in bars:
    height = bar.get_height()
    plt.gca().text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 3, str(int(height)) ,
                   ha='center', color='black', fontsize=11)

# %% [markdown]
# From the given dataset of Unempoyment some countries present their record late 2010 so inorder to understand the distribution of the datas I prefered to create a report from 2010. In this report my task is to get which country has the lowest and highest unemployment average rate
#  - 1 Korea had the least Unemployed country from the dataset
#  - 2 Makedonia an Eastern europe  country had the most Unemployed rate

# %% [markdown]
# ## Unemployment rate group by age under 15-24  from year 2022-01 to 2023-01

# %%
by_age=pd.read_csv('unemp_by_age.csv')
by_age.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 0     EA19     UNEMP   15_24   PC_LF         M  2022-01   14.4        NaN
# 1     EA19     UNEMP   15_24   PC_LF         M  2022-02   14.2        NaN
# 2     EA19     UNEMP   15_24   PC_LF         M  2022-03   14.2        NaN
# 3     EA19     UNEMP   15_24   PC_LF         M  2022-04   14.4        NaN
# 4     EA19     UNEMP   15_24   PC_LF         M  2022-05   14.1        NaN

# %% [markdown]
# ### Data Cleaning And Data wrangling

# %%
by_age.describe()
# Out:
#             Value
# count  478.000000
# mean    13.905626
# std      6.972023
# min      3.800000
# 25%      8.621132
# 50%     11.300000
# 75%     18.575000
# max     37.500000

# %%
by_age.TIME.max()
# Out:
# '2023-01'

# %%
by_age.TIME.min()
# Out:
# '2022-01'

# %%
by_age.TIME.head(10)
# Out:
# 0    2022-01
# 1    2022-02
# 2    2022-03
# 3    2022-04
# 4    2022-05
# 5    2022-06
# 6    2022-07
# 7    2022-08
# 8    2022-09
# 9    2022-10
# Name: TIME, dtype: object

# %%
by_age.isnull().sum()
# Out:
# LOCATION        0
# INDICATOR       0
# SUBJECT         0
# MEASURE         0
# FREQUENCY       0
# TIME            0
# Value           0
# Flag Codes    444
# dtype: int64

# %%
# Remove Flag Codes
by_age.drop(columns='Flag Codes',axis=1,inplace=True)
by_age.LOCATION.unique()
# Out:
# array(['EA19', 'SVN', 'ITA', 'AUS', 'LVA', 'G-7', 'CAN', 'USA', 'HUN',
#        'COL', 'LUX', 'DNK', 'TUR', 'DEU', 'OECD', 'NLD', 'ISL', 'ESP',
#        'POL', 'PRT', 'GRC', 'EST', 'IRL', 'LTU', 'SWE', 'FIN', 'KOR',
#        'BEL', 'GBR', 'CHL', 'AUT', 'ISR', 'SVK', 'CZE', 'JPN', 'MEX',
#        'FRA', 'NOR', 'EU27_2020', 'CRI'], dtype=object)

# %%
by_age.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value
# 0     EA19     UNEMP   15_24   PC_LF         M  2022-01   14.4
# 1     EA19     UNEMP   15_24   PC_LF         M  2022-02   14.2
# 2     EA19     UNEMP   15_24   PC_LF         M  2022-03   14.2
# 3     EA19     UNEMP   15_24   PC_LF         M  2022-04   14.4
# 4     EA19     UNEMP   15_24   PC_LF         M  2022-05   14.1

# %%
by_age.FREQUENCY.unique()
# Out:
# array(['M'], dtype=object)

# %%
sorted.head()
# Out:
#    LOCATION SUBJECT     Value
# 24      JPN   15_24  4.325000
# 8       DEU   15_24  5.750000
# 29      MEX   15_24  6.485505
# 22      ISR   15_24  6.875000
# 25      KOR   15_24  6.984352

# %%
sorted.shape
# Out:
# (40, 3)

# %%
# lets reanme some LOcations
by_age.LOCATION.unique()
# Out:
# array(['EA19', 'SVN', 'ITA', 'AUS', 'LVA', 'G-7', 'CAN', 'USA', 'HUN',
#        'COL', 'LUX', 'DNK', 'TUR', 'DEU', 'OECD', 'NLD', 'ISL', 'ESP',
#        'POL', 'PRT', 'GRC', 'EST', 'IRL', 'LTU', 'SWE', 'FIN', 'KOR',
#        'BEL', 'GBR', 'CHL', 'AUT', 'ISR', 'SVK', 'CZE', 'JPN', 'MEX',
#        'FRA', 'NOR', 'EU27_2020', 'CRI'], dtype=object)

# %%
beyond_2010.LOCATION.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'G7M', 'BGR', 'HRV', 'CYP', 'EST', 'ISR',
#        'LVA', 'LTU', 'MKD', 'MLT', 'RUS', 'SVN', 'ZAF', 'OECD', 'ROU',
#        'COL', 'CRI', 'NAM', 'EU27'], dtype=object)

# %%
# replace some Country names with proper names
by_age['LOCATION'].replace(['G-7','EU27_2020'],['G7M','EU27'],inplace=True)

# %%
len(y_2020.LOCATION.unique())
# Out:
# 48

# %%
len(by_age.LOCATION.unique())
# Out:
# 40

# %%
# %matplotlib inline
plt.figure(figsize=(10,7))
group_mean=by_age.groupby(['LOCATION','SUBJECT'])['Value'].mean().reset_index()
sorted =group_mean.sort_values(by='Value')
aged=plt.bar('LOCATION','Value',data=sorted,color=color)
plt.bar('LOCATION','Value')
# bar[0].set_color('#2fcfac')
# bar[20].set_color('#bbcced')
# bar[-1].set_color('#3dc22b')
plt.xticks(rotation='vertical')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
for bar in aged:
    height = bar.get_height()
    plt.gca().text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 3, str(int(height)) ,
                   ha='center', color='black', fontsize=11);

# %% [markdown]
# The unemployed are people of working age who are without work, are available for work, and have taken specific steps to find work. The uniform application of this definition results in estimates of unemployment rates that are more internationally comparable than estimates based on national definitions of unemployment. Unemployment rates are shown for two age groups: people aged 15 to 24 (those just entering the labour market following education); and people aged 25 and over. This indicator is measured in numbers of unemployed people as a percentage of the labour force and it is seasonally adjusted. The labour force is defined as the total number of unemployed people plus those in civilian employment. Data are based on labour force surveys (LFS).  For European Union countries where monthly LFS information is not available, the monthly unemployed figures are estimated by Eurostat

# %%
# %matplotlib notebook

plt.figure(figsize=(15,7))
Y_2020 = y_2020.groupby('LOCATION')['Value'].mean().reset_index()
by_mean=Y_2020.sort_values(by='Value',ascending= True)
bars = plt.bar('LOCATION','Value',data=by_mean,color=color)
aged=plt.bar('LOCATION','Value',data=sorted,color='orangered',alpha=.86)

plt.title('relationships b/n Unemloyment rate in 2020 for total ages  and\n aged between 15-24 from  01-2020 to 01-2023',pad=25,fontsize=20)
plt.xticks(rotation='vertical')
plt.yticks([])
for spine in plt.gca().spines.values():
    spine.set_visible(False)
for bar in aged:
    height = bar.get_height()
    plt.gca().text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 3, str(int(height)) ,
                   ha='center', color='black', fontsize=11);
for bar in bars:
    height = bar.get_height()
    plt.gca().text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 3, str(int(height)) ,
                   ha='center', color='black', fontsize=11);

# %% [markdown]
# From the above graph we will get that some of the datasets haven't full filled,  becouse the dataset of Unemployment group by age is having a list of 40 countries while all aged dataset have 48 country lists and some countries are in aged dataset but not in full aged.<br>
#
# That is why some of the bars have only a single value and the last such as  `AUS,EA19,CHL`. Those are informations that are not includede at the full aged Unemployment dataset<br>
# <u><b> What did we get from this report  </b></u><br>
#             1- Mekodenia Has the highest rate of Unemployment through out the years and eventhough its data for 01-2022to 01-2023 isnot informed it has the highst record<br>
#             2- korea,Japan  Israel and mexico has the least Unemployment rate on both all aged report and age between 15-24<br>
#             3- Japan has a greate significant change on creating jobs for fresh college students and aged b/n 15-24 and reduce a high value from 2020 reports on   01-2022 to 01-2023

# %% [markdown]
#  * which country has higher Unemployment

# %%
#Which state has the most data
import seaborn as sns
color = sns.color_palette()
cnt_srs = full_unemployment_by_age.LOCATION.value_counts()
cnt_srs.head()
# Out:
# NAM    54
# G7M    54
# USA    54
# FRA    47
# CAN    46
# Name: LOCATION, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[5])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('States', fontsize=12)
plt.title('Count the states', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\justice for all\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# take the mean of rate state by state
grouped_df = full_unemployment_by_age.groupby(["LOCATION"])["Value"].aggregate("mean").reset_index()
plt.figure(figsize=(12,8))
import seaborn as sns
sns.pointplot(grouped_df['LOCATION'].values, grouped_df['Value'].values, alpha=0.8, color=color[2])
plt.ylabel('Mean rate', fontsize=12)
plt.xlabel('States', fontsize=12)
plt.title("Average of mean", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\justice for all\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#See exact numbers
make_total = full_unemployment_by_age.pivot_table("Value",index=['LOCATION'],aggfunc='mean')
topstate=make_total.sort_values(by='Value',ascending=False)[:49]
topstate.head()
# Out:
#               Value
# LOCATION
# MKD       80.673147
# ZAF       60.848514
# ITA       58.848353
# SVK       58.263087
# BGR       56.352826

# %%
topstate.plot()
# Out:
# <AxesSubplot:xlabel='LOCATION'>

# %% [markdown]
# https://data.oecd.org/chart/6Zsa

# %% [markdown]
# <iframe src="https://data.oecd.org/chart/6Zsa" width="860" height="645" style="border: 0" mozallowfullscreen="true" webkitallowfullscreen="true" allowfullscreen="true"><a href="https://data.oecd.org/chart/6Zsa" target="_blank">OECD Chart: Unemployment rate by age group, 15-24 year-olds, % of labour force, Aug 2022 or latest available</a></iframe>
